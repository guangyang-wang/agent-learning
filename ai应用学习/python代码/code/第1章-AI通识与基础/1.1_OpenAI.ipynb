# %% [markdown]
# # OpenAI 调用大模型
#
# ## 0.准备工作
#
# 首先，我们需要安装OpenAI的依赖
# 安装命令：
# ```shell
# uv add openai
# ```

# %% [markdown]
# ## 1.初始化客户端
#
# ### 1.1.硬编码API_KEY

# %%
from openai import OpenAI

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-你的DeepSeek密钥",
    base_url="https://api.deepseek.com"
)

# %% [markdown]
# ### 1.2. 从环境变量中获取API_KEY

# %% [markdown]
# 读取环境变量需要用到python-dotenv，先安装依赖
# 安装命令：
# ```shell
# uv add python-dotenv
# ```
# 再创建.env文件，并写入api_key
# ```properties
# DEEPSEEK_API_KEY=sk-你的DeepSeek密钥
# ```
# 接着就可以可以从环境变量中获取api_key了

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("DEEPSEEK_API_KEY")
print(api_key)

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com"
)
# Out:
# sk-你的DeepSeek密钥

# %% [markdown]
# ## 2.访问模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 成功调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 成功调用大模型...

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "aeaf0641-f828-4790-9383-02dfbddb3211",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "你好！我是你的AI助教，一个专门设计来帮助你学习和解决问题的智能助手。我可以协助你解答问题、提供学习建议、解释概念，或者陪你讨论各种话题。有什么我可以帮你的吗？😊",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": null,
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1773826492,
#   "model": "deepseek-chat",
#   "object": "chat.completion",
#   "service_tier": null,
#   "system_fingerprint": "fp_eaab8d114b_prod0820_fp8_kvcache",
#   "usage": {
#     "completion_tokens": 45,
#     "prompt_tokens": 15,
#     "total_tokens": 60,
#     "completion_tokens_details": null,
#     "prompt_tokens_details": {
#       "audio_tokens": null,
#       "cached_tokens": 0
#     },
#     "prompt_cache_hit_tokens": 0,
#     "prompt_cache_miss_tokens": 15
#   }
# }

# %%
print(response.choices[0].message.content)
# Out:
# 你好！我是DeepSeek，由深度求索公司创造的AI助手。😊
#
# 我是一个纯文本模型，可以帮你解答各种问题、进行对话交流、协助处理文本任务等。虽然我不支持多模态识别，但我可以处理你上传的文件（比如图像、txt、pdf、ppt、word、excel等），从中读取文字信息来帮助你。
#
# 我完全免费使用，拥有128K的上下文长度，还支持联网搜索功能（需要你在Web/App中手动开启）。你可以通过官方应用商店下载我的App来使用。
#
# 有什么我可以帮助你的吗？无论是学习问题、工作协助还是日常聊天，我都很乐意为你提供帮助！✨
